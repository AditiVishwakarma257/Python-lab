# %% [markdown]
# <a href="https://colab.research.google.com/github/AditiVishwakarma257/Python-lab/blob/main/Copy_of_FirstProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('aditi');
# Out:
# aditi

# %%
print("Acropolois")
# Out:
# Acropolois

# %%
var = 10
var2 = 4.23333333
var3 = "India"
print(var ," ", var2 ," ", var3)

var = 7777
var = "Monu" , 3.14 , "njbdweb"
print(var)
# Out:
# 10   4.23333333   India
# ('Monu', 3.14, 'njbdweb')

# %%
firstname = input("Enter your first name")
lastname = input("Enter your first name")
# Out:
# Enter your first nameAditi
# Enter your first namevishwakarma

# %%
age = input("Enter your age")
print(int(age)+15);
# Out:
# Enter your age15
# 30

# %%
a = 10
print(str(a))
# Out:
# 10

# %%
b= '20'
print(int(b));
print(float(b));
# Out:
# 20
# 20.0

# %%
print(str.format("placeholder"))
# Out:
# placeholder

# %%
print("{} is genius".format("AV"))
# Out:
# AV is genius

# %%
x = 68
print(chr(x))
# Out:
# D

# %%
y= 77
print(chr(y))
# Out:
# M

# %%
char = 'X'
print(ord(char))
# Out:
# 88

# %%
print("AV"*10)
# Out:
# AVAVAVAVAVAVAVAVAVAV

# %%
print("AV " *10)
# Out:
# AV AV AV AV AV AV AV AV AV AV

# %%
for i in range(5)
print(i)
# Out:
#   File "/tmp/ipython-input-4248206105.py", line 1
#     for i in range(5)
#                       ^
# SyntaxError: expected ':'

# %%
for i  in range :
  print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-233002075.py in <cell line: 0>()
# ----> 1 for i  in range :
#       2   print(i)
#
# TypeError: 'type' object is not iterable

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(-4,0,-1):
  print("*"*i)

# %%
for i in range(4,0,-1):
  print("*"*i)
# Out:
# ****
# ***
# **
# *

# %%
for i in range(2 , 10 , +1)
print("*"*i)
# Out:
#   File "/tmp/ipython-input-978668980.py", line 1
#     for i in range(2 , 10 , +1)
#                                ^
# SyntaxError: expected ':'

# %%
for i in range(2 , 10 , +1):
 print("*"*i)
# Out:
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********

# %%
for i in range(1,6):
  print(" "*(6-i),"*"*i)
# Out:
#       *
#      **
#     ***
#    ****
#   *****

# %%
for i  in range(1,6):
  print(" "*(6-i) , "*"*((2*i)-1))
# Out:
#       *
#      ***
#     *****
#    *******
#   *********

# %%
val = 20
print(f"{val} value is even")
# Out:
# 20 value is even

# %%
word = "PYTHON"
a,b,c,d,e,f = word
print(a,b,c,d,e,f)
# Out:
# P Y T H O N

# %%
print("I like {1} , maggi and {0}".format("chochlate ", "ice-cream"));
# Out:
# I like ice-cream , maggi and chochlate

# %%
raman = "coffee"
riya = "tea"

raman, riya = riya, raman   # swapping

print("raman {}".format(raman))
print("riya {}".format(riya))
# Out:
# raman tea
# riya coffee

# %%
e,f,g,h,j,k,i,o, = 'acgthmko'
s = ord(e)+ord(f)+ord(g)+ord(h)+ord(j)+ord(k)+ord(i)+ord(o)

# %%
e,f,g,h,j,k,i,o, = 'acgthmko'
s = ord(e)+ord(f)+ord(g)+ord(h)+ord(j)+ord(k)+ord(i)+ord(o)

# %%
e,f,g,h,j,k,i,o, = 'acgthmko'
s = ord(e)+ord(f)+ord(g)+ord(h)+ord(j)+ord(k)+ord(i)+ord(o)
print(s)
# Out:
# 846

# %%
import math
print(math.sqrt(16))
print(math.floor(7.80982))
print(math.ceil(10.742727))
# Out:
# 4.0
# 7
# 11

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import random

x = random.random()
print(x * 2)
print(x * 2)
# Out:
# 1.1957206856598777
# 1.1957206856598777

# %%
import random

# %%
import random
y = random.randint(5,15)
print(y)
# Out:
# 12
